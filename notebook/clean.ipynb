# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Jupiter\Employee_project\data\emp_messy.csv", encoding="UTF-8")

# %%
print(df.shape)
# print(df.duplicated().sum())
print(df.drop_duplicates(inplace=True))
# Out:
# (1020, 18)
# None

# %%
df.columns
df.dtypes
df.shape
# Out:
# (955, 18)

# %% [markdown]
# *Employee ID*

# %%
df["employee_id"] = df["employee_id"].str.strip().str.upper()
df["employee_id"] = df["employee_id"].str.replace("-","", regex=False).str.replace(" ", "", regex=False)
print(df["employee_id"].unique())
df["employee_id"].nunique()
# df["employee_id"].head(20)
# Out:
# ['EMP00124' 'EMP00119' 'EMP00146' 'EMP00772' 'EMP00331' 'EMP00324'
#  'EMP00149' 'EMP00862' 'EMP00269' 'EMP00259' 'EMP00367' 'EMP00213'
#  'EMP00758' 'EMP00812' 'EMP00254' 'EMP00002' 'EMP00369' 'EMP00421'
#  'EMP00152' 'EMP00453' 'EMP00238' 'EMP00306' 'EMP00870' 'EMP00440'
#  'EMP00027' 'EMP00485' 'EMP00102' 'EMP00800' 'EMP00334' 'EMP00104'
#  'EMP00368' 'EMP00742' 'EMP00240' 'EMP00263' 'EMP00244' 'EMP00423'
#  'EMP00093' 'EMP00087' 'EMP00216' 'EMP00281' 'EMP00337' 'EMP00393'
#  'EMP00499' 'EMP00712' 'EMP00304' 'EMP00598' 'EMP00031' 'EMP00057'
#  'EMP00133' 'EMP00747' 'EMP00696' 'EMP00284' 'EMP00828' 'EMP00163'
#  'EMP00083' 'EMP00593' 'EMP00251' 'EMP00135' 'EMP00326' 'EMP00225'
#  'EMP00199' 'EMP00443' 'EMP00200' 'EMP00579' 'EMP00523' 'EMP00252'
#  'EMP00376' 'EMP00248' 'EMP00184' 'EMP00806' 'EMP00833' 'EMP00047'
#  'EMP00831' 'EMP00816' 'EMP00212' 'EMP00807' 'EMP00697' 'EMP00311'
#  'EMP00532' 'EMP00442' 'EMP00361' 'EMP00751' 'EMP00814' 'EMP00275'
#  'EMP00491' 'EMP00173' 'EMP00092' 'EMP00459' 'EMP00704' 'EMP00679'
#  'EMP00243' 'EMP00373' 'EMP00759' 'EMP00174' 'EMP00016' 'EMP00798'
#  'EMP00890' 'EMP00891' 'EMP00350' 'EMP00670' 'EMP00247' 'EMP00628'
#  'EMP00844' 'EMP00568' 'EMP00728' 'EMP00802' 'EMP00626' 'EMP00017'
#  'EMP00425' 'EMP00165' 'EMP00276' 'EMP00779' 'EMP00160' 'EMP00357'
#  'EMP00496' 'EMP00880' 'EMP00854' 'EMP00821' 'EMP00651' 'EMP00001'
#  'EMP00416' 'EMP00674' 'EMP00385' 'EMP00838' 'EMP00809' 'EMP00612'
#  'EMP00397' 'EMP00709' 'EMP00884' 'EMP00430' 'EMP00887' 'EMP00299'
#  'EMP00075' 'EMP00732' 'EMP00591' 'EMP00434' 'EMP00502' 'EMP00234'
#  'EMP00561' 'EMP00390' 'EMP00896' 'EMP00429' 'EMP00721' 'EMP00893'
#  'EMP00608' 'EMP00855' 'EMP00371' 'EMP00411' 'EMP00877' 'EMP00881'
#  'EMP00588' 'EMP00683' 'EMP00053' 'EMP00019' 'EMP00488' 'EMP00717'
#  'EMP00412' 'EMP00043' 'EMP00786' 'EMP00007' 'EMP00233' 'EMP00198'
#  'EMP00333' 'EMP00142' 'EMP00004' 'EMP00555' 'EMP00858' 'EMP00237'
#  'EMP00130' 'EMP00469' 'EMP00291' 'EMP00040' 'EMP00441' 'EMP00380'
#  'EMP00622' 'EMP00840' 'EMP00850' 'EMP00204' 'EMP00895' 'EMP00282'
#  'EMP00006' 'EMP00359' 'EMP00030' 'EMP00175' 'EMP00554' 'EMP00613'
#  'EMP00381' 'EMP00109' 'EMP00339' 'EMP00052' 'EMP00811' 'EMP00813'
#  'EMP00294' 'EMP00876' 'EMP00863' 'EMP00180' 'EMP00520' 'EMP00285'
#  'EMP00467' 'EMP00122' 'EMP00188' 'EMP00114' 'EMP00771' 'EMP00405'
#  'EMP00632' 'EMP00128' 'EMP00058' 'EMP00415' 'EMP00486' 'EMP00089'
#  'EMP00493' 'EMP00639' 'EMP00024' 'EMP00640' 'EMP00063' 'EMP00274'
#  'EMP00627' 'EMP00648' 'EMP00783' 'EMP00526' 'EMP00604' 'EMP00599'
#  'EMP00428' 'EMP00147' 'EMP00221' 'EMP00475' 'EMP00682' 'EMP00470'
#  'EMP00106' 'EMP00388' 'EMP00500' 'EMP00068' 'EMP00045' 'EMP00168'
#  'EMP00432' 'EMP00071' 'EMP00723' 'EMP00874' 'EMP00773' 'EMP00129'
#  'EMP00867' 'EMP00492' 'EMP00479' 'EMP00003' 'EMP00574' 'EMP00051'
#  'EMP00864' 'EMP00478' 'EMP00314' 'EMP00562' 'EMP00745' 'EMP00505'
#  'EMP00552' 'EMP00409' 'EMP00706' 'EMP00103' 'EMP00879' 'EMP00824'
#  'EMP00111' 'EMP00473' 'EMP00219' 'EMP00819' 'EMP00072' 'EMP00399'
#  'EMP00061' 'EMP00355' 'EMP00676' 'EMP00508' 'EMP00792' 'EMP00207'
#  'EMP00115' 'EMP00077' 'EMP00338' 'EMP00729' 'EMP00084' 'EMP00261'
#  'EMP00452' 'EMP00187' 'EMP00264' 'EMP00818' 'EMP00681' 'EMP00318'
#  'EMP00511' 'EMP00714' 'EMP00280' 'EMP00775' 'EMP00694' 'EMP00695'
#  'EMP00722' 'EMP00584' 'EMP00748' 'EMP00302' 'EMP00450' 'EMP00716'
#  'EMP00316' 'EMP00898' 'EMP00702' 'EMP00185' 'EMP00646' 'EMP00228'
#  'EMP00796' 'EMP00827' 'EMP00869' 'EMP00582' 'EMP00148' 'EMP00678'
#  'EMP00701' 'EMP00286' 'EMP00193' 'EMP00166' 'EMP00524' 'EMP00610'
#  'EMP00144' 'EMP00091' 'EMP00310' 'EMP00303' 'EMP00497' 'EMP00038'
#  'EMP00322' 'EMP00349' 'EMP00015' 'EMP00583' 'EMP00195' 'EMP00690'
#  'EMP00778' 'EMP00673' 'EMP00842' 'EMP00161' 'EMP00544' 'EMP00761'
#  'EMP00810' 'EMP00283' 'EMP00009' 'EMP00182' 'EMP00223' 'EMP00570'
#  'EMP00757' 'EMP00064' 'EMP00730' 'EMP00845' 'EMP00616' 'EMP00596'
#  'EMP00154' 'EMP00123' 'EMP00521' 'EMP00101' 'EMP00557' 'EMP00894'
#  'EMP00307' 'EMP00209' 'EMP00460' 'EMP00808' 'EMP00145' 'EMP00301'
#  'EMP00615' 'EMP00791' 'EMP00332' 'EMP00653' 'EMP00125' 'EMP00257'
#  'EMP00495' 'EMP00541' 'EMP00196' 'EMP00586' 'EMP00738' 'EMP00793'
#  'EMP00563' 'EMP00444' 'EMP00803' 'EMP00231' 'EMP00774' 'EMP00780'
#  'EMP00176' 'EMP00208' 'EMP00438' 'EMP00062' 'EMP00431' 'EMP00206'
#  'EMP00056' 'EMP00644' 'EMP00205' 'EMP00112' 'EMP00715' 'EMP00733'
#  'EMP00449' 'EMP00875' 'EMP00597' 'EMP00567' 'EMP00025' 'EMP00741'
#  'EMP00746' 'EMP00767' 'EMP00607' 'EMP00865' 'EMP00410' 'EMP00519'
#  'EMP00533' 'EMP00483' 'EMP00657' 'EMP00768' 'EMP00518' 'EMP00222'
#  'EMP00120' 'EMP00889' 'EMP00752' 'EMP00426' 'EMP00667' 'EMP00305'
#  'EMP00534' 'EMP00507' 'EMP00155' 'EMP00848' 'EMP00158' 'EMP00617'
#  'EMP00127' 'EMP00288' 'EMP00330' 'EMP00506' 'EMP00372' 'EMP00480'
#  'EMP00131' 'EMP00689' 'EMP00353' 'EMP00037' 'EMP00201' 'EMP00749'
#  'EMP00156' 'EMP00899' 'EMP00531' 'EMP00079' 'EMP00192' 'EMP00630'
#  'EMP00375' 'EMP00403' 'EMP00197' 'EMP00389' 'EMP00406' 'EMP00823'
#  'EMP00178' 'EMP00378' 'EMP00529' 'EMP00032' 'EMP00060' 'EMP00126'
#  'EMP00856' 'EMP00731' 'EMP00726' 'EMP00826' 'EMP00022' 'EMP00543'
#  'EMP00401' 'EMP00226' 'EMP00097' 'EMP00654' 'EMP00462' 'EMP00448'
#  'EMP00658' 'EMP00851' 'EMP00536' 'EMP00546' 'EMP00427' 'EMP00671'
#  'EMP00843' 'EMP00637' 'EMP00589' 'EMP00634' 'EMP00530' 'EMP00085'
#  'EMP00054' 'EMP00686' 'EMP00684' 'EMP00669' 'EMP00739' 'EMP00872'
#  'EMP00647' 'EMP00328' 'EMP00382' 'EMP00585' 'EMP00116' 'EMP00484'
#  'EMP00256' 'EMP00088' 'EMP00611' 'EMP00323' 'EMP00861' 'EMP00553'
#  'EMP00134' 'EMP00194' 'EMP00575' 'EMP00655' 'EMP00760' 'EMP00490'
#  'EMP00487' 'EMP00387' 'EMP00766' 'EMP00073' 'EMP00211' 'EMP00514'
#  'EMP00538' 'EMP00754' 'EMP00458' 'EMP00055' 'EMP00023' 'EMP00691'
#  'EMP00466' 'EMP00279' 'EMP00081' 'EMP00569' 'EMP00571' 'EMP00363'
#  'EMP00528' 'EMP00190' 'EMP00313' 'EMP00446' 'EMP00719' 'EMP00137'
#  'EMP00100' 'EMP00578' 'EMP00169' 'EMP00424' 'EMP00836' 'EMP00550'
#  'EMP00287' 'EMP00215' 'EMP00262' 'EMP00139' 'EMP00594' 'EMP00797'
#  'EMP00241' 'EMP00245' 'EMP00358' 'EMP00042' 'EMP00035' 'EMP00236'
#  'EMP00110' 'EMP00873' 'EMP00348' 'EMP00652' 'EMP00290' 'EMP00720'
#  'EMP00859' 'EMP00255' 'EMP00272' 'EMP00846' 'EMP00710' 'EMP00787'
#  'EMP00386' 'EMP00540' 'EMP00642' 'EMP00664' 'EMP00364' 'EMP00883'
#  'EMP00008' 'EMP00656' 'EMP00121' 'EMP00266' 'EMP00724' 'EMP00504'
#  'EMP00781' 'EMP00422' 'EMP00620' 'EMP00510' 'EMP00191' 'EMP00150'
#  'EMP00141' 'EMP00825' 'EMP00835' 'EMP00065' 'EMP00765' 'EMP00892'
#  'EMP00782' 'EMP00383' 'EMP00159' 'EMP00740' 'EMP00560' 'EMP00400'
#  'EMP00012' 'EMP00013' 'EMP00046' 'EMP00878' 'EMP00711' 'EMP00356'
#  'EMP00041' 'EMP00210' 'EMP00232' 'EMP00525' 'EMP00345' 'EMP00461'
#  'EMP00235' 'EMP00107' 'EMP00698' 'EMP00693' 'EMP00214' 'EMP00344'
#  'EMP00036' 'EMP00713' 'EMP00384' 'EMP00157' 'EMP00151' 'EMP00132'
#  'EMP00600' 'EMP00649' 'EMP00860' 'EMP00777' 'EMP00321' 'EMP00011'
#  'EMP00277' 'EMP00404' 'EMP00888' 'EMP00108' 'EMP00391' 'EMP00315'
#  'EMP00685' 'EMP00300' 'EMP00703' 'EMP00346' 'EMP00347' 'EMP00454'
#  'EMP00095' 'EMP00788' 'EMP00641' 'EMP00834' 'EMP00476' 'EMP00688'
#  'EMP00699' 'EMP00743' 'EMP00852' 'EMP00537' 'EMP00635' 'EMP00407'
#  'EMP00619' 'EMP00603' 'EMP00665' 'EMP00672' 'EMP00082' 'EMP00319'
#  'EMP00868' 'EMP00573' 'EMP00618' 'EMP00171' 'EMP00278' 'EMP00577'
#  'EMP00551' 'EMP00374' 'EMP00587' 'EMP00638' 'EMP00249' 'EMP00402'
#  'EMP00559' 'EMP00494' 'EMP00005' 'EMP00675' 'EMP00601' 'EMP00565'
#  'EMP00489' 'EMP00512' 'EMP00755' 'EMP00545' 'EMP00623' 'EMP00822'
#  'EMP00220' 'EMP00138' 'EMP00590' 'EMP00498' 'EMP00351' 'EMP00556'
#  'EMP00395' 'EMP00437' 'EMP00566' 'EMP00465' 'EMP00456' 'EMP00342'
#  'EMP00181' 'EMP00517' 'EMP00849' 'EMP00327' 'EMP00066' 'EMP00170'
#  'EMP00770' 'EMP00736' 'EMP00010' 'EMP00784' 'EMP00539' 'EMP00179'
#  'EMP00659' 'EMP00164' 'EMP00218' 'EMP00785' 'EMP00592' 'EMP00847'
#  'EMP00853' 'EMP00662' 'EMP00094' 'EMP00309' 'EMP00547' 'EMP00804'
#  'EMP00246' 'EMP00805' 'EMP00900' 'EMP00663' 'EMP00143' 'EMP00396'
#  'EMP00296' 'EMP00377' 'EMP00820' 'EMP00513' 'EMP00336' 'EMP00857'
#  'EMP00457' 'EMP00687' 'EMP00177' 'EMP00735' 'EMP00753' 'EMP00885'
#  'EMP00668' 'EMP00832' 'EMP00451' 'EMP00186' 'EMP00750' 'EMP00472'
#  'EMP00341' 'EMP00069' 'EMP00343' 'EMP00105' 'EMP00522' 'EMP00886'
#  'EMP00882' 'EMP00167' 'EMP00660' 'EMP00866' 'EMP00014' 'EMP00815'
#  'EMP00633' 'EMP00841' 'EMP00224' 'EMP00799' 'EMP00239' 'EMP00756'
#  'EMP00549' 'EMP00229' 'EMP00581' 'EMP00268' 'EMP00445' 'EMP00794'
#  'EMP00631' 'EMP00595' 'EMP00692' 'EMP00398' 'EMP00463' 'EMP00558'
#  'EMP00871' 'EMP00298' 'EMP00408' 'EMP00242' 'EMP00705' 'EMP00737'
#  'EMP00477' 'EMP00666' 'EMP00897' 'EMP00700' 'EMP00455' 'EMP00435'
#  'EMP00606' 'EMP00636' 'EMP00680' 'EMP00572' 'EMP00049' 'EMP00744'
#  'EMP00417' 'EMP00394' 'EMP00203' 'EMP00564' 'EMP00118' 'EMP00447'
#  'EMP00317' 'EMP00320' 'EMP00379' 'EMP00021' 'EMP00267' 'EMP00576'
#  'EMP00837' 'EMP00098' 'EMP00090' 'EMP00172' 'EMP00471' 'EMP00474'
#  'EMP00273' 'EMP00329' 'EMP00621' 'EMP00033' 'EMP00503' 'EMP00183'
#  'EMP00769' 'EMP00099' 'EMP00509' 'EMP00605' 'EMP00039' 'EMP00645'
#  'EMP00096' 'EMP00354' 'EMP00548' 'EMP00265' 'EMP00340' 'EMP00420'
#  'EMP00086' 'EMP00370' 'EMP00727' 'EMP00270' 'EMP00419' 'EMP00734'
#  'EMP00230' 'EMP00034' 'EMP00790' 'EMP00708' 'EMP00433' 'EMP00365'
#  'EMP00360' 'EMP00271' 'EMP00070' 'EMP00602' 'EMP00515' 'EMP00020'
#  'EMP00580' 'EMP00501' 'EMP00189' 'EMP00113' 'EMP00308' 'EMP00253'
#  'EMP00335' 'EMP00044' 'EMP00140' 'EMP00067' 'EMP00162' 'EMP00725'
#  'EMP00677' 'EMP00830' 'EMP00789' 'EMP00707' 'EMP00801' 'EMP00392'
#  'EMP00527' 'EMP00764' 'EMP00076' 'EMP00080' 'EMP00535' 'EMP00059'
#  'EMP00614' 'EMP00366' 'EMP00289' 'EMP00829' 'EMP00074' 'EMP00260'
#  'EMP00312' 'EMP00217' 'EMP00292' 'EMP00227' 'EMP00468' 'EMP00050'
#  'EMP00153' 'EMP00650' 'EMP00482' 'EMP00293' 'EMP00516' 'EMP00297'
#  'EMP00250' 'EMP00839' 'EMP00352' 'EMP00362' 'EMP00661' 'EMP00414'
#  'EMP00464' 'EMP00048' 'EMP00117' 'EMP00202' 'EMP00763' 'EMP00018'
#  'EMP00625' 'EMP00325' 'EMP00026' 'EMP00295' 'EMP00817' 'EMP00418'
#  'EMP00624' 'EMP00136' 'EMP00609' 'EMP00776' 'EMP00762' 'EMP00481'
#  'EMP00028' 'EMP00718' 'EMP00439' 'EMP00643' 'EMP00029' 'EMP00436'
#  'EMP00413' 'EMP00629' 'EMP00542' 'EMP00078' 'EMP00795' 'EMP00258']
# 900

# %% [markdown]
# *Name*

# %%
df["name"].shape
df["name"] = df["name"].str.strip().str.lower().str.title()
print(df["name"].unique())
# Out:
# ['Meera Nair' 'Amit Kumar' 'Sakshi Singh' 'Rahul Patel' 'Deepak Verma'
#  'Aarav Sharma' 'Vivaan Verma' 'Ananya Sharma' 'Siddharth Jain'
#  'Kavya Gupta' 'Muskan Gupta' 'Karan Joshi' 'Riya Jain' 'Aditya-Singh'
#  'Nisha Roy' 'Isha Kapoor' 'Divya Joshi' 'Aditya Singh' 'Ritesh Kumar'
#  'Deepak-Verma' 'Pooja Yadav' 'Arjun Gupta' 'Aarav-Sharma' 'Tanya Kapoor'
#  'Akash Patel' 'Sneha Singh' 'Manish Tiwari' 'Harsh Vardhan' 'Sneha-Singh'
#  'Rohan Mehta' 'Siddharth  Jain' 'Priya Verma' 'Tanya-Kapoor'
#  'Priya-Verma' 'Sanjay Mishra' 'Isha-Kapoor' 'Neha Mehta' 'Sanjay-Mishra'
#  'Komal Sharma' 'Vivaan-Verma' 'Akash  Patel' 'Sakshi  Singh'
#  'Kavya  Gupta' 'Sneha  Singh' 'Amit  Kumar' 'Harsh-Vardhan'
#  'Manish-Tiwari' 'Sakshi-Singh' 'Rahul-Patel' 'Rahul  Patel'
#  'Komal  Sharma' 'Akash-Patel' 'Karan-Joshi' 'Ananya-Sharma'
#  'Komal-Sharma' 'Vivaan  Verma' 'Divya  Joshi' 'Pooja-Yadav'
#  'Ritesh-Kumar' 'Meera  Nair' 'Rohan  Mehta' 'Riya  Jain' 'Ritesh  Kumar'
#  'Rohan-Mehta' 'Neha-Mehta' 'Arjun  Gupta' 'Sanjay  Mishra' 'Muskan-Gupta'
#  'Nisha  Roy']

# %% [markdown]
# *Age*

# %%
# df["age"].shape
print(df["age"].isnull().sum())
(df["age"].unique())
df["age"] = df["age"].replace({"unknown":np.nan,
                                   "?":np.nan,
                                   "Thirty":30,
                                   "30yrs":30,
                                   "25 years":25,
                                   "age 35":35,
                                   29.5:29})


df["age"] = pd.to_numeric(df["age"],errors="coerce")
print(df["age"].dtype)
df.loc[(df["age"] < 16) | (df["age"] > 70), "age"] = np.nan
print((df["age"].unique()))
df["age"] = df["age"].fillna(df["age"].median()).astype(int)
# Out:
# 46
# float64
# [29.5 47.   nan 37.  53.  38.  51.  24.  25.  29.  22.  50.  30.  23.
#  35.  58.  55.  42.  57.  28.  21.  44.  48.  26.  39.  52.  56.  59.
#  36.  17.  27.  34.  60.  46.  43.  54.  32.  31.  41.  45.  40.  33.
#  49. ]

# %% [markdown]
# *gender*

# %%
df["gender"] = df["gender"].replace({"Femal":"Female",
                                   "male":"Male",
                                   "?":np.nan,
                                   "Woman":"Female",
                                   "F":"Female",
                                   "female":"Female",
                                   "Man":"Male",
                                   "M":"Male"})
df["gender"] = df["gender"].replace(np.nan,"Unknown")

print(df["gender"].unique())
# Out:
# ['Female' 'Other' 'Unknown' 'Male']

# %% [markdown]
# *department*

# %%
df["department"].nunique()
# df["department"].unique()
df["department"] = df["department"].str.strip().replace({"it":"IT",
                          "I.T.":"IT",
                          "Marketting":"Marketing",
                          "SALES":"Sales",
                          "Research & Development":"R&D",
                          "Information Technology":"IT",
                          "Ops":"Operations",
                          "Finanace":"Finance",
                          "Finaace":"Finance",
                          "Human Resources":"HR",
                          "Cust Support":"Customer Support"})
df["department"].unique()
# Out:
# array(['Legal', 'Engineering', 'Marketing', 'Operations',
#        'Customer Support', 'Finance', 'Sales', 'IT', 'R&D', 'HR', nan,
#        'Unknown'], dtype=object)

# %% [markdown]
# *job_role*

# %%
df["job_role"].nunique()
df["job_role"].unique()
df["job_role"] = df["job_role"].str.strip().replace({"Analyst":"Data Analist",
                                    "software engineer":"Engineer",
                                    "Software Engg":"Engineer",
                                    "BDE": "Business Development Executive",
                                    "Sales Exec":"Sales Executive",
                                    "QA":"Quality Assurance",
                                    "HR Exec":"HR Executive",
                                    "HR Ececutive":"HR Executive"})
df["job_role"].unique()
# Out:
# array(['Data Analist', nan, 'Manager', 'Engineer', 'Executive',
#        'Recruiter', 'Business Development Executive', 'Sales Executive',
#        'Unknown', 'Quality Assurance', 'HR Executive'], dtype=object)

# %% [markdown]
# *city*

# %%
df["city"].nunique()
df["city"].unique()
df["city"] = df["city"].str.strip().replace({"Chennai,":"Chennai",
                                             "indore":"Indore",
                                             "Puna":"Pune",
                                             "Delhi":"Delhi NCR",
                                             "Hyderabad":"Hydrabad",
                                             "Ahmedabad":"Ahemdabad",
                                             "New Delhi":"Delhi NCR",
                                             "Bengaluru":"Bangalore",
                                             np.nan:"Unknown"})
df["city"].unique()
# Out:
# array(['Bhopal', 'Nagpur', 'Kolkata', 'Hydrabad', 'Bangalore',
#        'Ahemdabad', 'Pune', 'Chennai', 'Indore', 'Jaipur', 'Unknown',
#        'Delhi NCR', 'Mumbai'], dtype=object)

# %% [markdown]
# *education*

# %%
df["education"].nunique()
df["education"].unique()
df["education"] = df["education"].str.strip().str.lower().str.title().replace({"BTECH":"B.Tech",
                                                                               "Mba":"MBA",
                                                                               "Mca":"MCA",
                                                                               "Bba":"BBA",
                                                                               "Phd":"PHD",
                                                                               "Be":"B.E.",
                                                                               "B Tech":"B.Tech",
                                                                               "Bcom":"B.Com",
                                                                               "M.B.A":"MBA",
                                                                               "Btech":"B.Tech",
                                                                               np.nan:"Unknown"})
df["education"].unique()
# Out:
# array(['B.Tech', 'M.Tech', 'Unknown', 'MBA', 'B.E.', 'MCA', 'B.Sc', 'BBA',
#        'Graduate', 'B.Com', 'PHD', 'Masters', 'M.Com', 'Diploma'],
#       dtype=object)

# %% [markdown]
# *experience_years*

# %%
# df["experience_years"].nunique()
# df["experience_years"].unique()
print(df["experience_years"].isnull().sum())

df["experience_years"] = df["experience_years"].astype(str).str.strip().replace({"five":5,
                                                         "30 yrs":"30",
                                                         "3.5 yrs":"3.5",
                                                         "5 years":"5",
                                                         "10yrs":10,
                                                         "unknown":np.nan,
                                                         "?":np.nan,
                                                         "20+":20
})

df["experience_years"] = pd.to_numeric(df["experience_years"],errors="coerce")
df.loc[df["experience_years"] < 0, "experience_years"] = np.nan
df["experience_years"] = df["experience_years"].fillna(df["experience_years"].median())

print(df["experience_years"].unique())
print(df["experience_years"].isnull().sum())

# %% [markdown]
# *salary*

# %%
# print(df["salary"].value_counts())
# df["salary"].isnull().sum()
# print(df["salary"].unique())
df["salary"] = df["salary"].replace({"unknown":np.nan,
                                     "?":np.nan,
                                     "N/A":np.nan
})

mask = df["salary"].astype("string").str.contains("crore", na=False)

df.loc[mask, "salary"] = (
    df.loc[mask, "salary"]
    .astype("string")
    .str.replace("crore", "", regex=False)
    .astype(float)
    * 10000000
)

mask = df["salary"].astype("string").str.contains("lpa|lakh|LPA", regex=True, na=False)

df.loc[mask, "salary"] = (
    df.loc[mask, "salary"]
    .astype("string")
    .str.replace("lpa", "", regex=False)
    .str.replace("LPA", "", regex=False)
    .str.replace("lakh", "", regex=False)
    .str.strip()
    .astype(float)
    * 100000
)
                            

mask = df["salary"].astype("string").str.endswith("k", na=False)
df.loc[mask, "salary"] = df.loc[mask, "salary"].astype("string").str.replace("k","", regex=False).astype(float) * 1000


df["salary"] = (
    df["salary"]
    .astype("string")
    .str.replace("₹", "", regex=False)
    .str.replace("rs.", "", regex=False)
    .str.replace("Rs. ", "", regex=False)
    .str.replace("inr", "", regex=False)
    .str.replace("INR", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.strip()
)
df["salary"] = pd.to_numeric(df["salary"], errors="coerce")
df.loc[df["salary"] <= 0, "salary"] = np.nan
df["salary"] = df["salary"].fillna(df["salary"].median())
print(df["salary"].isnull().sum())
print(df["salary"].value_counts())
print(df["salary"].unique())

# %% [markdown]
# *performance rating*

# %%
print(df["performance_rating"].unique())
# print(df["performance_rating"].value_counts())
df["performance_rating"] = df["performance_rating"].replace({"three":3,
                                                             "Good":4,
                                                             "Average":6,
                                                             "Poor":2,
                                                             "4 stars":4,
                                                             "Excellent":9,
                                                             "Rating 4":4,
                                                             "5/5":5
})

df["performance_rating"] = pd.to_numeric(df["performance_rating"], errors="coerce")
df["performance_rating"] = df["performance_rating"].fillna(df["performance_rating"].median())
print(df["performance_rating"].unique())

# %% [markdown]
# *overtime*

# %%
print(df["overtime"].unique())
df["overtime"] = df["overtime"].str.strip().replace({"Y":"Yes",
                                        "N":"No",
                                        "False":"No",
                                        "TRUE":"Yes",
                                        "yes":"Yes",
                                        "YES":"Yes"
})
print(df["overtime"].unique())

# %% [markdown]
# *work_mode*

# %%
print(df["work_mode"].unique())
df["work_mode"] = df["work_mode"].str.strip().replace({"Work From Home":"WHF",
                                                       "remote":"Remote",
                                                       "REMOTE":"Remote",
                                                       "On-site":"Onsite",
                                                       "Home":"WFH",
                                                       "WHF":"WFH"
})
print(df["work_mode"].unique())
# Out:
# ['WFH' 'Hybrid' nan 'Remote' 'Onsite' 'unknown' 'Office' 'WHF']
# ['WFH' 'Hybrid' nan 'Remote' 'Onsite' 'unknown' 'Office']

# %% [markdown]
# *projects_handled*

# %%
print(df["projects_handled"].unique())
df["projects_handled"] = df["projects_handled"].replace({"zero":0,
                                                        "none":0,
                                                        "20 projects":20,
                                                        "5-6":5.5,
                                                        "3.0":3,
                                                        "15+":15,
                                                        "5 projects":5,
                                                        "-1":np.nan,
                                                        "many":np.nan,
                                                        "unknown":np.nan})
df["projects_handled"] = pd.to_numeric(df["projects_handled"], errors="coerce")
df["projects_handled"] = df["projects_handled"].fillna(df["projects_handled"].median())
print(df["projects_handled"].unique())

# %% [markdown]
# *training_hours*

# %%
# print(df["training_hours"].unique())
df["training_hours"] = df["training_hours"].replace({"none":0,
                                                     "1 week":40,
                                                     "5 days":40,
                                                     "20h":20,
                                                     "40 hrs":40,
                                                     "zero":0,
                                                     "40-50":45,
                                                     "unknown":np.nan,
                                                     "200+":200,
                                                     "100 hours":100,
                                                     })

df["training_hours"] = df["training_hours"].fillna(df["training_hours"].median())
# print(df["training_hours"].unique())
# print(df["training_hours"].isnull().sum())

# %% [markdown]
# *promotion_status*

# %%
print(df["promotion_status"].unique())
df["promotion_status"] = df["promotion_status"].str.strip().replace({"yes":"Yes",
                                                                     "Not Promoted":"No",
                                                                     "Y":"Yes",
                                                                     "YES":"Yes",
                                                                     "unknown":np.nan,
                                                                     "N":"No",
                                                                     "Promoted":"Yes",
                                                                     "Pending":"No"})
df["promotion_status"] = df["promotion_status"].fillna(df["promotion_status"].mode()[0])
print(df["promotion_status"].unique())
df["promotion_status"].value_counts(dropna=False)
# Out:
# ['No' 'Yes' nan 'Promoted' 'Pending']
# ['No' 'Yes']
# promotion_status
# No     505
# Yes    450
# Name: count, dtype: int64

# %% [markdown]
# *attrition_status*

# %%
print(df["attrition_status"].unique())
df["attrition_status"] = df["attrition_status"].str.strip().replace({"Active":"No",
                                                                    "Resigned":"Yes",
                                                                    "Y":"Yes",
                                                                    "yes":"Yes",
                                                                    "Stayed":"No",
                                                                    "Left":"Yes",
                                                                    "unknown":np.nan,
                                                                    "N":"No",
                                                                    "YES":"Yes"})

df["attrition_status"] = df["attrition_status"].fillna(df["attrition_status"].mode()[0])
print(df["attrition_status"].unique())
# Out:
# ['No' 'Yes']
# ['No' 'Yes']

# %% [markdown]
# *joining_date*

# %%
# print(df["joining_date"].unique())
df["joining_date"] = df["joining_date"].replace({"?":np.nan,
                                                 "unknown":np.nan,
                                                 "4":np.nan})

df["joining_date"] = pd.to_datetime(df["joining_date"], errors="coerce", dayfirst=True, format="mixed")
print(df["joining_date"].unique())
print(df["joining_date"].isnull().sum())
# Out:
# <DatetimeArray>
# ['2018-09-04 00:00:00', '2014-06-15 00:00:00', '2021-06-10 00:00:00',
#  '2023-03-04 00:00:00', '2021-09-16 00:00:00', '2020-05-23 00:00:00',
#  '2014-06-02 00:00:00', '2025-09-29 00:00:00', '2019-08-15 00:00:00',
#  '2025-12-06 00:00:00',
#  ...
#  '2021-08-20 00:00:00', '2024-08-28 00:00:00', '2013-03-14 00:00:00',
#  '2019-09-10 00:00:00', '2025-06-08 00:00:00', '2020-07-22 00:00:00',
#  '2014-08-22 00:00:00', '2021-06-26 00:00:00', '2016-01-13 00:00:00',
#  '2018-07-23 00:00:00']
# Length: 720, dtype: datetime64[ns]
# 123

# %%
# ==================================================
# FINAL DATASET CHECKLIST
# ==================================================


# 1. Dataset Shape
print("SHAPE:")
print(df.shape)


# 2. Column Names
print("\nCOLUMN NAMES:")
print(df.columns.tolist())


# 3. Data Types
print("\nDATA TYPES:")
print(df.dtypes)


# 4. Dataset Information
print("\nDATASET INFO:")
df.info()


# 5. Missing Values
print("\nMISSING VALUES:")
print(df.isnull().sum())


# 6. Total Missing Values
print("\nTOTAL MISSING VALUES:")
print(df.isnull().sum().sum())


# 7. Duplicate Rows
print("\nDUPLICATE ROWS:")
print(df.duplicated().sum())


# 8. Unique Values Count
print("\nUNIQUE VALUES COUNT:")
print(df.nunique())


# 9. Numeric Columns Summary
print("\nNUMERIC COLUMNS SUMMARY:")
print(df.describe())


# 10. Categorical Columns Summary
print("\nCATEGORICAL COLUMNS SUMMARY:")
print(df.describe(include="object"))


# ==================================================
# 11. CHECK FINAL CATEGORICAL VALUES
# ==================================================

categorical_columns = [
    "gender",
    "department",
    "city",
    "education_level",
    "job_role",
    "promotion_status",
    "attrition_status"
]

print("\nCATEGORICAL COLUMN VALUES:")

for col in categorical_columns:
    print(f"\n{col.upper()}:")
    print(df[col].unique())
    print("Missing:", df[col].isnull().sum())


# ==================================================
# 12. CHECK NUMERIC RANGE
# ==================================================

numeric_columns = [
    "age",
    "experience_years",
    "salary",
    "training_hours",
    "backlogs"
]

print("\nNUMERIC COLUMN MIN/MAX:")

for col in numeric_columns:
    print(f"\n{col.upper()}")
    print("Min:", df[col].min())
    print("Max:", df[col].max())


# ==================================================
# 13. CHECK NEGATIVE VALUES
# ==================================================

print("\nNEGATIVE VALUE CHECK:")

for col in [
    "age",
    "experience_years",
    "salary",
    "training_hours",
    "backlogs"
]:
    print(
        f"{col} negative values:",
        (df[col] < 0).sum()
    )


# ==================================================
# 14. CHECK AGE RANGE
# ==================================================

print("\nAGE RANGE CHECK:")

print(
    "Invalid Age Values:",
    ((df["age"] < 18) | (df["age"] > 100)).sum()
)


# ==================================================
# 15. CHECK EXPERIENCE RANGE
# ==================================================

print("\nEXPERIENCE CHECK:")

print(
    "Invalid Experience:",
    (df["experience_years"] < 0).sum()
)


# ==================================================
# 16. CHECK DATE COLUMN
# ==================================================

print("\nDATE COLUMN CHECK:")

date_columns = [
    "joining_date"
]

for col in date_columns:
    print(f"\n{col}:")
    print("Missing:", df[col].isnull().sum())
    print("Data type:", df[col].dtype)
    print("Minimum Date:", df[col].min())
    print("Maximum Date:", df[col].max())


# ==================================================
# 17. CHECK DUPLICATE EMPLOYEE IDs
# ==================================================

print("\nDUPLICATE EMPLOYEE ID CHECK:")

print(
    df["employee_id"].duplicated().sum()
)


# ==================================================
# 18. FINAL RANDOM SAMPLE
# ==================================================

print("\nFINAL DATA SAMPLE:")

print(df.sample(10, random_state=42))
# Out:
# SHAPE:
# (955, 18)
#
# COLUMN NAMES:
# ['employee_id', 'name', 'age', 'gender', 'department', 'job_role', 'city', 'education', 'experience_years', 'salary', 'performance_rating', 'overtime', 'work_mode', 'projects_handled', 'training_hours', 'promotion_status', 'attrition_status', 'joining_date']
#
# DATA TYPES:
# employee_id                   object
# name                          object
# age                            int64
# gender                        object
# department                    object
# job_role                      object
# city                          object
# education                     object
# experience_years             float64
# salary                       Float64
# performance_rating           float64
# overtime                      object
# work_mode                     object
# projects_handled             float64
# training_hours                object
# promotion_status              object
# attrition_status              object
# joining_date          datetime64[ns]
# dtype: object
#
# DATASET INFO:
# <class 'pandas.core.frame.DataFrame'>
# Index: 955 entries, 0 to 1019
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         955 non-null    object
#  1   name                955 non-null    object
#  2   age                 955 non-null    int64
#  3   gender              955 non-null    object
#  4   department          917 non-null    object
#  5   job_role            922 non-null    object
#  6   city                955 non-null    object
#  7   education           955 non-null    object
#  8   experience_years    955 non-null    float64
#  9   salary              955 non-null    Float64
#  10  performance_rating  955 non-null    float64
#  11  overtime            905 non-null    object
#  12  work_mode           926 non-null    object
#  13  projects_handled    955 non-null    float64
#  14  training_hours      955 non-null    object
#  15  promotion_status    955 non-null    object
#  16  attrition_status    955 non-null    object
#  17  joining_date        832 non-null    datetime64[ns]
# dtypes: Float64(1), datetime64[ns](1), float64(3), int64(1), object(12)
# memory usage: 142.7+ KB
#
# MISSING VALUES:
# employee_id             0
# name                    0
# age                     0
# gender                  0
# department             38
# job_role               33
# city                    0
# education               0
# experience_years        0
# salary                  0
# performance_rating      0
# overtime               50
# work_mode              29
# projects_handled        0
# training_hours          0
# promotion_status        0
# attrition_status        0
# joining_date          123
# dtype: int64
#
# TOTAL MISSING VALUES:
# 273
#
# DUPLICATE ROWS:
# 0
#
# UNIQUE VALUES COUNT:
# employee_id           900
# name                   69
# age                    41
# gender                  4
# department             11
# job_role               10
# city                   13
# education              14
# experience_years      163
# salary                714
# performance_rating      9
# overtime                4
# work_mode               6
# projects_handled       19
# training_hours        123
# promotion_status        2
# attrition_status        2
# joining_date          719
# dtype: int64
#
# NUMERIC COLUMNS SUMMARY:
#               age  experience_years          salary  performance_rating  \
# count  955.000000        955.000000           955.0          955.000000
# mean    38.832461          7.475183   990342.006283            3.285864
# min     17.000000          0.000000        150000.0            0.000000
# 25%     29.500000          4.350000        600000.0            2.000000
# 50%     38.000000          6.800000        823315.0            3.000000
# 75%     48.000000          9.950000       1107965.5            4.000000
# max     60.000000         30.000000      10000000.0           10.000000
# std     11.436508          5.165484  1155877.737255            1.826591
#
#        projects_handled                   joining_date
# count        955.000000                            832
# mean           5.759162  2019-08-14 21:45:00.000000256
# min            0.000000            2013-01-01 00:00:00
# 25%            3.000000            2016-03-25 18:00:00
# 50%            5.000000            2019-05-22 00:00:00
# 75%            8.000000            2022-12-06 18:00:00
# max           20.000000            2026-08-07 00:00:00
# std            4.278635                            NaN
#
# CATEGORICAL COLUMNS SUMMARY:
#        employee_id          name  gender department  job_role    city  \
# count          955           955     955        917       922     955
# unique         900            69       4         11        10      13
# top       EMP00047  Muskan Gupta  Female         IT  Engineer  Indore
# freq             2            44     308        162       231     101
#
#        education overtime work_mode  training_hours promotion_status  \
# count        955      905       926             955              955
# unique        14        4         6             123                2
# top       B.Tech       No    Remote              40               No
# freq         105      450       297              58              505
#
#        attrition_status
# count               955
# unique                2
# top                  No
# freq                753
#
# CATEGORICAL COLUMN VALUES:
#
# GENDER:
# ['Female' 'Other' 'Unknown' 'Male']
# Missing: 0
#
# DEPARTMENT:
# ['Legal' 'Engineering' 'Marketing' 'Operations' 'Customer Support'
#  'Finance' 'Sales' 'IT' 'R&D' 'HR' nan 'Unknown']
# Missing: 38
#
# CITY:
# ['Bhopal' 'Nagpur' 'Kolkata' 'Hydrabad' 'Bangalore' 'Ahemdabad' 'Pune'
#  'Chennai' 'Indore' 'Jaipur' 'Unknown' 'Delhi NCR' 'Mumbai']
# Missing: 0
#
# EDUCATION_LEVEL:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'education_level'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 74
#      72 for col in categorical_columns:
#      73     print(f"\n{col.upper()}:")
# ---> 74     print(df[col].unique())
#      75     print("Missing:", df[col].isnull().sum())
#      78 # ==================================================
#      79 # 12. CHECK NUMERIC RANGE
#      80 # ==================================================
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'education_level'
